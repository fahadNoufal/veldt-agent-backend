# %%
import sys
import os

sys.path.append(os.path.abspath(".."))
# from agents.stylist_agent import StylistAgent

# %%
from agents.stylist_agent import StylistAgent
styleAgent = StylistAgent()
# Out:
# 14:57:26 | WARNING | google_genai._api_client | Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.

# %%
await styleAgent.chat(user_message='casual vibe',
        history=[{'role': 'human',
   'content': 'i need a dress for my brothers bday party, its at night, i need classic syle relaxed fit dress.'},
  {'role': 'ai',
   'content': '{\n  "type": "question",\n  "questions": "Happy birthday to your brother! To help me find the perfect dress, could you tell me if you prefer a more casual or a more dressed-up vibe for the party?"\n}'}])
# Out:
# 15:15:27 | INFO | agents.stylist_agent | [Stylist] chat called — history_turns=2  message='casual vibe'
# 15:15:27 | INFO | google_genai.models | AFC is enabled with max remote calls: 10.
# 15:15:32 | INFO | agents.stylist_agent | [Stylist] parsed response type=suggestion
# {'response': {'type': 'suggestion',
#   'suggestion': 'A relaxed-fit, midi-length A-line dress in a breathable cotton-linen blend with subtle vertical stripes would be perfect for a casual, classic evening celebration.',
#   'message': 'This dress offers comfort and timeless style.',
#   'follow_up': "How does that sound for your brother's birthday party?",
#   'user_preference': "occasion: brother's birthday party, time_of_day: night, style_preference: classic, casual, fit_preference: relaxed fit"},
#  'history': [{'role': 'human',
#    'content': 'i need a dress for my brothers bday party, its at night, i need classic syle relaxed fit dress.'},
#   {'role': 'ai',
#    'content': '{\n  "type": "question",\n  "questions": "Happy birthday to your brother! To help me find the perfect dress, could you tell me if you prefer a more casual or a more dressed-up vibe for the party?"\n}'},
#   {'role': 'human', 'content': 'casual vibe'},
#   {'role': 'ai',
#    'content': '{\n  "type": "suggestion",\n  "suggestion": "A relaxed-fit, midi-length A-line dress in a breathable cotton-linen blend with subtle vertical stripes would be perfect for a casual, classic evening celebration.",\n  "message": "This dress offers comfort and timeless style.",\n  "follow_up": "How does that sound for your brother\'s birthday party?",\n  "user_preference": "occasion: brother\'s birthday party, time_of_day: night, style_preference: classic, casual, fit_preference: relaxed fit"\n}'}],
#  'raw': '{\n  "type": "suggestion",\n  "suggestion": "A relaxed-fit, midi-length A-line dress in a breathable cotton-linen blend with subtle vertical stripes would be perfect for a casual, classic evening celebration.",\n  "message": "This dress offers comfort and timeless style.",\n  "follow_up": "How does that sound for your brother\'s birthday party?",\n  "user_preference": "occasion: brother\'s birthday party, time_of_day: night, style_preference: classic, casual, fit_preference: relaxed fit"\n}'}

# %%
from agents.search_agent import SearchAgent

searchAgent= SearchAgent()

# %%
await searchAgent.search(query='white dress')
product_index.faiss
# Out:
# 16:14:02 | INFO | agents.search_agent | [SearchAgent] Loading CLIP model on device=cpu
# 16:14:06 | ERROR | agents.search_agent | [SearchAgent] FAISS index not found at 'product_index.faiss   # CLIP product FAISS index'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 await searchAgent.search(query='white dress')
#
# File ~/programFiles/projects/ai-projects/ecommerse-support-agent/support-agent/agents/search_agent.py:105, in SearchAgent.search(self, query, top_k)
#      99 """
#     100 Async wrapper around the blocking CLIP search.
#     101
#     102 Returns a list of zero-padded product ID strings, e.g. ["0023", "0045"].
#     103 """
#     104 loop = asyncio.get_event_loop()
# --> 105 return await loop.run_in_executor(None, self._search_sync, query, top_k)
#
# File ~/anaconda3/envs/ml-proj/lib/python3.13/concurrent/futures/thread.py:59, in _WorkItem.run(self)
#      56     return
#      58 try:
# ---> 59     result = self.fn(*self.args, **self.kwargs)
#      60 except BaseException as exc:
#      61     self.future.set_exception(exc)
#
# File ~/programFiles/projects/ai-projects/ecommerse-support-agent/support-agent/agents/search_agent.py:78, in SearchAgent._search_sync(self, query, top_k)
#      75 """Blocking CLIP search — call via asyncio executor."""
#      76 import torch
# ---> 78 self._initialize()
#      79 log.debug("[SearchAgent] Encoding query: %r  top_k=%d", query, top_k)
#      81 inputs = self.processor(
#      82     text=[query], return_tensors="pt", padding=True
#      83 ).to(self.device)
#
# File ~/programFiles/projects/ai-projects/ecommerse-support-agent/support-agent/agents/search_agent.py:63, in SearchAgent._initialize(self)
#      61 if not os.path.exists(FAISS_INDEX_PATH):
#      62     log.error("[SearchAgent] FAISS index not found at '%s'", FAISS_INDEX_PATH)
# ---> 63     raise FileNotFoundError(
#      64         f"FAISS index not found at '{FAISS_INDEX_PATH}'. "
#      65         "Please build it first with the indexing script."
#      66     )
#      67 self.index = faiss.read_index(FAISS_INDEX_PATH)
#      68 log.info("[SearchAgent] FAISS index loaded — %d products indexed", self.index.ntotal)
#
# FileNotFoundError: FAISS index not found at 'product_index.faiss   # CLIP product FAISS index'. Please build it first with the indexing script.
